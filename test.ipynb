# %%
#question 1

import pandas as pd
binSize = pd.read_csv('E:/machine_test/BinSize.csv')
temperature = pd.read_csv('E:/machine_test/temperature.csv')
print(binSize)
print(temperature)
# Out:
#                 ID  LATITUDE  LONGITUDE  ELEVATION STATE                 NAME  \
# 0      AE000041196    25.333     55.517       34.0   NaN  SHARJAH INTER. AIRP
# 1      AEM00041194    25.255     55.364       10.4   NaN           DUBAI INTL
# 2      AEM00041217    24.433     54.651       26.8   NaN       ABU DHABI INTL
# 3      AEM00041218    24.262     55.609      264.9   NaN          AL AIN INTL
# 4      AFM00040990    31.500     65.850     1010.0   NaN     KANDAHAR AIRPORT
# ...            ...       ...        ...        ...   ...                  ...
# 18254  ZA000067633   -15.250     23.150     1053.0   NaN                MONGU
# 18255  ZA000067743   -17.817     25.817      986.0   NaN          LIVINGSTONE
# 18256  ZI000067775   -17.917     31.133     1480.0   NaN     HARARE (KUTSAGA)
# 18257  ZI000067975   -20.067     30.867     1095.0   NaN             MASVINGO
# 18258  ZI000067983   -20.200     32.616     1132.0   NaN             CHIPINGE
#
# ...

# %%
#question 2

import pandas as pd
weather = pd.read_csv('E:/machine_test/weather.csv')
print(weather)
# Out:
#     Year    Fires       Acres
# 0   2019   50 477   4 664 364
# 1   2018   58 083   8 767 492
# 2   2017   71 499  10 026 086
# 3   2016   67 743   5 509 995
# 4   2015   68 151  10 125 149
# ..   ...      ...         ...
# 89  1930  190 980  52 266 000
# 90  1929  134 895  46 230 000
# 91  1928  175 934  43 542 000
# 92  1927  158 438  38 531 000
# 93  1926   91 793  24 316 000
#
# [94 rows x 3 columns]

# %%
#question 3

#1

select pname,kname from person,kids,proj,dept,employ where pname="payment management" and dname="computer" and employ.pno=person.pno and kids.pno=employ.pno and dept.dno=person.dno

#2

select * from person,proj,works_on where works_on.prno=proj.prno and works_on.pno=person.pno

#3

select pname,pnosup,grade from person,employ where employ.pno=person.pno
